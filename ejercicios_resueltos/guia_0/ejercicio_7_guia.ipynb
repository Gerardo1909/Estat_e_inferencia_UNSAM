# %% [markdown]
# # Ejercicio 7 - guía 0

# %% [markdown]
# Para cada una de las siguientes distribuciones graficar la PDF y la CDF. Calcular media, mediana, moda, error estándar y, si amerita, algunos percentiles.

# %% [markdown]
# ## a)
#
# Normal estándar N(0,1)

# %%
from utils.graficos_dist import graficar_pdf_scipy, graficar_cdf_scipy
from scipy.stats import norm

normal_cero_uno = norm(loc=0, scale=1)

# %%
# Gráfico de la PDF
graficar_pdf_scipy(norm, "Distribución normal N(0,1)")

# %%
# Gráfico de la CDF
graficar_cdf_scipy(normal_cero_uno, "Distribución normal N(0,1)")

# %%
# Cálculo de media, mediana, moda y error estándar
import pprint
from utils.func_distr import calcular_moda

dict_datos = {
    "Media": normal_cero_uno.mean(),
    "Mediana": normal_cero_uno.median(),
    "Moda": calcular_moda(normal_cero_uno),
    "Error estándar": normal_cero_uno.std()
}

pprint.pprint(dict_datos)
# Out:
# {'Error estándar': np.float64(1.0),
#  'Media': np.float64(0.0),
#  'Mediana': np.float64(0.0),
#  'Moda': np.float64(-0.0030933256317995372)}
